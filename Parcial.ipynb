# %%
from google.colab import drive
drive.mount('/content/gdrive')
import sys

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
import sys
sys.path.append('/content/gdrive/My Drive/PrimerParcial/fc2-exam-primercorte2020i-Yeinner/')

# %%
import pandas as pd
from numpy import *
from pylab import *
from momento import mdistribucion

# %%
data = loadtxt('gdrive/My Drive/PrimerParcial/fc2-exam-primercorte2020i-Yeinner/planets_2020.04.13_08.06.56.tab')

# %%
a=mdistribucion(data[:,0])   #Periodo Orbital
b=mdistribucion(data[:,1])   #Distancia Orbital
c=mdistribucion(data[:,2])   #Excentricidad
d=mdistribucion(data[:,3])   #Ángulo de Inclinación
e=mdistribucion(data[:,4])   #Masa del Planeta
f=mdistribucion(data[:,5])   #Radio del Planeta
g=mdistribucion(data[:,6])   #Densidad del planeta
h=mdistribucion(data[:,7])   #Distancia Desde la Tierra
i=mdistribucion(data[:,8])   #Temperatura Efectiva de la Estrella 
j=mdistribucion(data[:,9])   #Masa de la Estrella
k=mdistribucion(data[:,10])  #Radio de la Estrella

# %% [markdown]
# #MEDIA

# %%
print("La media del periodo orbital es: ", format(a.med(), '.2f'))
print("La media de la distancia orbital es: ", format(b.med(), '.2f'))
print("La media de la excentricidad es: ", format(c.med(), '.2f'))
print("La media del ángulo de la inclinación es: ", format(d.med(), '.2f'))
print("La media de la massa de los planetas es: ", format(e.med(), '.2f'))
print("La media de los radios de los planetas es: ", format(f.med(), '.2f'))
print("La media de la densidad de los planetas es: ", format(g.med(), '.2f'))
print("La media de la distancias desde la tierra es: ", format(h.med(), '.2f'))
print("La media de la temperatura de la estrella es: ", format(i.med(), '.2f'))
print("La media de la masa de las estrellas es: ", format(j.med(), '.2f'))
print("La media de las radios de las estrellas es: ", format(k.med(), '.2f'))
# Out:
# La media del periodo orbital es:  22.25
# La media de la distancia orbital es:  0.11
# La media de la excentricidad es:  0.14
# La media del ángulo de la inclinación es:  87.49
# La media de la massa de los planetas es:  1.40
# La media de los radios de los planetas es:  0.94
# La media de la densidad de los planetas es:  2.10
# La media de la distancias desde la tierra es:  525.09
# La media de la temperatura de la estrella es:  5526.67
# La media de la masa de las estrellas es:  1.02
# La media de las radios de las estrellas es:  1.18

# %% [markdown]
# #VARIANZA

# %%
print("Variacion del periodo:", format(a.var(), '.2f'))
print("Variacion de la distancia orbital es: ", format(b.var(), '.2f'))
print("Variacion de la excentricidad es: ", format(c.var(), '.2f'))
print("Variacion del ángulo de la inclinación es: ", format(d.var(), '.2f'))
print("Variacion de la massa de los planetas es: ", format(e.var(), '.2f'))
print("Variacion de los radios de los planetas es: ", format(f.var(), '.2f'))
print("Variacion de la densidad de los planetas es: ", format(g.var(), '.2f'))
print("Variacion de la distancias desde la tierra es: ", format(h.var(), '.2f'))
print("Variacion de la temperatura de la estrella es: ", format(i.var(), '.2f'))
print("Variacion de la masa de las estrellas es: ", format(j.var(), '.2f'))
print("Variacion de las radios de las estrellas es: ", format(k.var(), '.2f'))
# Out:
# Variacion del periodo: 6301.38
# Variacion de la distancia orbital es:  0.04
# Variacion de la excentricidad es:  0.02
# Variacion del ángulo de la inclinación es:  5.03
# Variacion de la massa de los planetas es:  8.46
# Variacion de los radios de los planetas es:  0.22
# Variacion de la densidad de los planetas es:  8.96
# Variacion de la distancias desde la tierra es:  178314.25
# Variacion de la temperatura de la estrella es:  691768.51
# Variacion de la masa de las estrellas es:  0.08
# Variacion de las radios de las estrellas es:  0.27

# %% [markdown]
# #DESVIACION ESTANDAR

# %%
print("La desviación Estandar del periodo:", format(a.des(), '.2f'))
print("La desviación Estandar de la distancia orbital es: ", format(b.des(), '.2f'))
print("La desviación Estandar de la excentricidad es: ", format(c.des(), '.2f'))
print("La desviación Estandar del ángulo de la inclinación es: ", format(d.des(), '.2f'))
print("La desviación Estandar de la massa de los planetas es: ", format(e.des(), '.2f'))
print("La desviación Estandar de los radios de los planetas es: ", format(f.des(), '.2f'))
print("La desviación Estandar de la densidad de los planetas es: ", format(g.des(), '.2f'))
print("La desviación Estandar de la distancias desde la tierra es: ", format(h.des(), '.2f'))
print("La desviación Estandar de la temperatura de la estrella es: ", format(i.des(), '.2f'))
print("La desviación Estandar de la masa de las estrellas es: ", format(j.des(), '.2f'))
print("La desviación Estandar de las radios de las estrellas es: ", format(k.des(), '.2f'))
# Out:
# La desviación Estandar del periodo: 79.38
# La desviación Estandar de la distancia orbital es:  0.19
# La desviación Estandar de la excentricidad es:  0.15
# La desviación Estandar del ángulo de la inclinación es:  2.24
# La desviación Estandar de la massa de los planetas es:  2.91
# La desviación Estandar de los radios de los planetas es:  0.47
# La desviación Estandar de la densidad de los planetas es:  2.99
# La desviación Estandar de la distancias desde la tierra es:  422.27
# La desviación Estandar de la temperatura de la estrella es:  831.73
# La desviación Estandar de la masa de las estrellas es:  0.29
# La desviación Estandar de las radios de las estrellas es:  0.52

# %% [markdown]
# #SKEW

# %%
print("Skew del periodo:", format(a.skw(), '.2f'))
print("Skew de la distancia orbital es: ", format(b.skw(), '.2f'))
print("Skew de la excentricidad es: ", format(c.skw(), '.2f'))
print("Skew del ángulo de la inclinación es: ", format(d.skw(), '.2f'))
print("Skew de la massa de los planetas es: ", format(e.skw(), '.2f'))
print("Skew de los radios de los planetas es: ", format(f.skw(), '.2f'))
print("Skew de la densidad de los planetas es: ", format(g.skw(), '.2f'))
print("Skew de la distancias desde la tierra es: ", format(h.skw(), '.2f'))
print("Skew de la temperatura de la estrella es: ", format(i.skw(), '.2f'))
print("Skew de la masa de las estrellas es: ", format(j.skw(), '.2f'))
print("Skew de las radios de las estrellas es: ", format(k.skw(), '.2f'))
# Out:
# Skew del periodo: 10.30
# Skew de la distancia orbital es:  5.86
# Skew de la excentricidad es:  1.87
# Skew del ángulo de la inclinación es:  -1.53
# Skew de la massa de los planetas es:  5.28
# Skew de los radios de los planetas es:  -0.34
# Skew de la densidad de los planetas es:  3.28
# Skew de la distancias desde la tierra es:  1.89
# Skew de la temperatura de la estrella es:  -1.40
# Skew de la masa de las estrellas es:  -0.84
# Skew de las radios de las estrellas es:  1.41

# %% [markdown]
# #KURTOSIS

# %%
print("Kurtosis del periodo:", format(a.Kur(), '.2f'))
print("Kurtosis de la distancia orbital es: ", format(b.Kur(), '.2f'))
print("Kurtosis de la excentricidad es: ", format(c.Kur(), '.2f'))
print("Kurtosis del ángulo de la inclinación es: ", format(d.Kur(), '.2f'))
print("Kurtosis de la massa de los planetas es: ", format(e.Kur(), '.2f'))
print("Kurtosis de los radios de los planetas es: ", format(f.Kur(), '.2f'))
print("Kurtosis de la densidad de los planetas es: ", format(g.Kur(), '.2f'))
print("Kurtosis de la distancias desde la tierra es: ", format(h.Kur(), '.2f'))
print("Kurtosis de la temperatura de la estrella es: ", format(i.Kur(), '.2f'))
print("Kurtosis de la masa de las estrellas es: ", format(j.Kur(), '.2f'))
print("Kurtosis de las radios de las estrellas es: ", format(k.Kur(), '.2f'))
# Out:
# Kurtosis del periodo: 125.87
# Kurtosis de la distancia orbital es:  47.60
# Kurtosis de la excentricidad es:  3.67
# Kurtosis del ángulo de la inclinación es:  3.55
# Kurtosis de la massa de los planetas es:  36.04
# Kurtosis de los radios de los planetas es:  -0.83
# Kurtosis de la densidad de los planetas es:  16.02
# Kurtosis de la distancias desde la tierra es:  7.19
# Kurtosis de la temperatura de la estrella es:  3.50
# Kurtosis de la masa de las estrellas es:  2.46
# Kurtosis de las radios de las estrellas es:  5.00

# %% [markdown]
# #COVARIANZA ENTRE PERIODO Y DISTANCIA DESDE LA TIERRA

# %%
m=mdistribucion(data)
print("\nLa covarianza es: ", format(m.cova(), '.2f'))
print("\nLa correlación es: ", format(m.cor(), '.2f'))
# Out:
# La covarianza es:  0.12
#
# La correlación es:  0.81

# %% [markdown]
# Por los valores obtenidos de estos dos terminos vemos que vemos que los dos datos son directamente dependientes y que los dos crecen o decrecen a la vez

# %% [markdown]
# #GRAFICA DEL PERIODO Y DISTANCIA DESDE LA TIERRA

# %%
x=data[:,0]
y=data[:,7]
plot(x)  #Grafica de periodo (Azul)
plot(z)  #Grafica de la distancia respecto a la tierra (naranja)

# %% [markdown]
# Vemos que la distancia desde la tierra tiene un comportamiento mas constante, esto es algo logico ya que este parammetro no tiene relacion con el tamaño de la estrella ni de su masa o temperatura, mientras que el periodo de orbita es irregular en cada dato, esto es dibido a las caracteristicas de la estrella o planeta

# %% [markdown]
# #SEGUNDO PUNTO

# %%
filePath = 'gdrive/My Drive/PrimerParcial/fc2-exam-primercorte2020i-Yeinner/Casos1_13abr2020.csv'

datos = pd.read_csv(filePath) # Leyendo datos desde el archivo Casos1.csv

# %%
dataSex = pd.DataFrame(datos, columns= ['Fecha de diagnóstico','Sexo','Edad', 'Atención**'])

# %%
histo = dataSex.groupby('Edad')['Sexo'].sum() # Suma el número de apariciones de M y F: Masculino, Femenino
histAten = dataSex.groupby('Edad')['Atención**'].sum()

# %%
male = histo.str.count('M')
female = histo.str.count('F')
total = male.sum()+female.sum()

print("hombres:",male.sum(), "Porcentaje de: ", round((male.sum()/total)*100,2), "%")
print("Mujeres:",female.sum(), "Porcentaje de: ", round((female.sum()/total)*100,2), "%")
print("Total:", total)
# Out:
# hombres: 1405 Porcentaje de:  50.61 %
# Mujeres: 1371 Porcentaje de:  49.39 %
# Total: 2776
